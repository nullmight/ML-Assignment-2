# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
mnist = tf.keras.datasets.mnist
(x_train, y_train),(x_test, y_test) = mnist.load_data()
# Out:
# ...
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
plt.imshow(x_train[7], cmap="gray")
plt.show()

# %%
x_train = tf.keras.utils.normalize(x_train, axis=1)
x_test = tf.keras.utils.normalize(x_test, axis=1)

# %%
model1 = tf.keras.Sequential([
    tf.keras.Input(shape=(28,28)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(150,activation="sigmoid"),
    tf.keras.layers.Dense(10,activation="softmax")
])
model1.compile(optimizer="adam",loss="sparse_categorical_crossentropy")
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 150)               117750
#
#  dense_1 (Dense)             (None, 10)                1510
#
# ...
# Total params: 119,260
# Trainable params: 119,260
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model1.fit(x=x_train, y=y_train, epochs=100)
plt.plot(history.history['loss'])
plt.show()
test_loss = model1.evaluate(x=x_test, y=y_test)
print("Training loss = {}".format(test_loss))
# Out:
# Epoch 1/100
# 1875/1875 [==============================] - 9s 2ms/step - loss: 0.4907
# Epoch 2/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2490
# Epoch 3/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1930
# Epoch 4/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1550
# Epoch 5/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1271
# Epoch 6/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1061
# Epoch 7/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0902
# Epoch 8/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0774
# Epoch 9/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0671
# Epoch 10/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0582
# Epoch 11/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0511
# Epoch 12/100
# ...

# %%
pred = model1.predict([x_test])
plt.imshow(x_test[9], cmap="gray")
plt.show()
print("Prediction: ",np.argmax(pred[9]))
# Out:
# 313/313 [==============================] - 1s 1ms/step
# Prediction:  9

# %%
model2 = tf.keras.Sequential([
    tf.keras.Input(shape=(28,28)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(150,activation="tanh"),
    tf.keras.layers.Dense(10,activation="softmax")
])
model2.compile(optimizer="adam",loss="sparse_categorical_crossentropy")
model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten_1 (Flatten)         (None, 784)               0
#
#  dense_2 (Dense)             (None, 150)               117750
#
#  dense_3 (Dense)             (None, 10)                1510
#
# ...
# Total params: 119,260
# Trainable params: 119,260
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model2.fit(x=x_train, y=y_train, epochs=100)
plt.plot(history.history['loss'])
plt.show()
test_loss = model2.evaluate(x=x_test, y=y_test)
print("Training loss = {}".format(test_loss))
# Out:
# Epoch 1/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.3450
# Epoch 2/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1924
# Epoch 3/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1325
# Epoch 4/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0982
# Epoch 5/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0756
# Epoch 6/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0594
# Epoch 7/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0478
# Epoch 8/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0379
# Epoch 9/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0306
# Epoch 10/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0241
# Epoch 11/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0194
# Epoch 12/100
# ...

# %%
model3 = tf.keras.Sequential([
    tf.keras.Input(shape=(28,28)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(150,activation="relu"),
    tf.keras.layers.Dense(10,activation="softmax")
])
model3.compile(optimizer="adam",loss="sparse_categorical_crossentropy")
model3.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 150)               117750
#
#  dense_1 (Dense)             (None, 10)                1510
#
# ...
# Total params: 119,260
# Trainable params: 119,260
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model3.fit(x=x_train, y=y_train, epochs=100)
plt.plot(history.history['loss'])
plt.show()
test_loss = model3.evaluate(x=x_test, y=y_test)
print("Training loss = {}".format(test_loss))
# Out:
# Epoch 1/100
# 1875/1875 [==============================] - 11s 2ms/step - loss: 0.3066
# Epoch 2/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1375
# Epoch 3/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0917
# Epoch 4/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0684
# Epoch 5/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0515
# Epoch 6/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0403
# Epoch 7/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0318
# Epoch 8/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0242
# Epoch 9/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0200
# Epoch 10/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0158
# Epoch 11/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0122
# Epoch 12/100
# ...

# %%
model4 = tf.keras.Sequential([
    tf.keras.Input(shape=(28,28)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(150,activation="sigmoid"),
    tf.keras.layers.Dense(100,activation="sigmoid"),
    tf.keras.layers.Dense(10,activation="softmax")
])
model4.compile(optimizer="adam",loss="sparse_categorical_crossentropy")
model4.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten_1 (Flatten)         (None, 784)               0
#
#  dense_2 (Dense)             (None, 150)               117750
#
#  dense_3 (Dense)             (None, 100)               15100
#
#  dense_4 (Dense)             (None, 10)                1010
#
# ...
# Total params: 133,860
# Trainable params: 133,860
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model4.fit(x=x_train, y=y_train, epochs=100)
plt.plot(history.history['loss'])
plt.show()
test_loss = model4.evaluate(x=x_test, y=y_test)
print("Training loss = {}".format(test_loss))
# Out:
# Epoch 1/100
# 1875/1875 [==============================] - 6s 2ms/step - loss: 0.5271
# Epoch 2/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2207
# Epoch 3/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1672
# Epoch 4/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1322
# Epoch 5/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1074
# Epoch 6/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0877
# Epoch 7/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0729
# Epoch 8/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0609
# Epoch 9/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0515
# Epoch 10/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0435
# Epoch 11/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0363
# Epoch 12/100
# ...

# %%
model5 = tf.keras.Sequential([
    tf.keras.Input(shape=(28,28)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(150,activation="sigmoid"),
    tf.keras.layers.Dense(100,activation="relu"),
    tf.keras.layers.Dense(10,activation="softmax")
])
model5.compile(optimizer="adam",loss="sparse_categorical_crossentropy")
model5.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten_2 (Flatten)         (None, 784)               0
#
#  dense_5 (Dense)             (None, 150)               117750
#
#  dense_6 (Dense)             (None, 100)               15100
#
#  dense_7 (Dense)             (None, 10)                1010
#
# ...
# Total params: 133,860
# Trainable params: 133,860
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model5.fit(x=x_train, y=y_train, epochs=100)
plt.plot(history.history['loss'])
plt.show()
test_loss = model5.evaluate(x=x_test, y=y_test)
print("Training loss = {}".format(test_loss))
# Out:
# Epoch 1/100
# 1875/1875 [==============================] - 6s 2ms/step - loss: 0.4254
# Epoch 2/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2138
# Epoch 3/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1580
# Epoch 4/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1212
# Epoch 5/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0965
# Epoch 6/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0784
# Epoch 7/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0647
# Epoch 8/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0543
# Epoch 9/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0445
# Epoch 10/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0376
# Epoch 11/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0310
# Epoch 12/100
# ...

# %%
model6 = tf.keras.Sequential([
    tf.keras.Input(shape=(28,28)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(150,activation="sigmoid"),
    tf.keras.layers.Dense(100,activation="tanh"),
    tf.keras.layers.Dense(10,activation="softmax")
])
model6.compile(optimizer="adam",loss="sparse_categorical_crossentropy")
model6.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 150)               117750
#
#  dense_1 (Dense)             (None, 100)               15100
#
#  dense_2 (Dense)             (None, 10)                1010
#
# ...
# Total params: 133,860
# Trainable params: 133,860
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model6.fit(x=x_train, y=y_train, epochs=100)
plt.plot(history.history['loss'])
plt.show()
test_loss = model6.evaluate(x=x_test, y=y_test)
print("Training loss = {}".format(test_loss))
# Out:
# Epoch 1/100
# 1875/1875 [==============================] - 18s 6ms/step - loss: 0.4124
# Epoch 2/100
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.2110
# Epoch 3/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.1535
# Epoch 4/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1169
# Epoch 5/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0912
# Epoch 6/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0743
# Epoch 7/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0619
# Epoch 8/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0492
# Epoch 9/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0416
# Epoch 10/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0337
# Epoch 11/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0279
# Epoch 12/100
# ...

# %%
model7 = tf.keras.Sequential([
    tf.keras.Input(shape=(28,28)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(150,activation="tanh"),
    tf.keras.layers.Dense(100,activation="sigmoid"),
    tf.keras.layers.Dense(10,activation="softmax")
])
model7.compile(optimizer="adam",loss="sparse_categorical_crossentropy")
model7.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten_1 (Flatten)         (None, 784)               0
#
#  dense_3 (Dense)             (None, 150)               117750
#
#  dense_4 (Dense)             (None, 100)               15100
#
#  dense_5 (Dense)             (None, 10)                1010
#
# ...
# Total params: 133,860
# Trainable params: 133,860
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model7.fit(x=x_train, y=y_train, epochs=100)
plt.plot(history.history['loss'])
plt.show()
test_loss = model7.evaluate(x=x_test, y=y_test)
print("Training loss = {}".format(test_loss))
# Out:
# Epoch 1/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4321
# Epoch 2/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2216
# Epoch 3/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1634
# Epoch 4/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1257
# Epoch 5/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0981
# Epoch 6/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0799
# Epoch 7/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0651
# Epoch 8/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0542
# Epoch 9/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0455
# Epoch 10/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0377
# Epoch 11/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0327
# Epoch 12/100
# ...

# %%
model8 = tf.keras.Sequential([
    tf.keras.Input(shape=(28,28)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(150,activation="tanh"),
    tf.keras.layers.Dense(100,activation="relu"),
    tf.keras.layers.Dense(10,activation="softmax")
])
model8.compile(optimizer="adam",loss="sparse_categorical_crossentropy")
model8.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten_2 (Flatten)         (None, 784)               0
#
#  dense_6 (Dense)             (None, 150)               117750
#
#  dense_7 (Dense)             (None, 100)               15100
#
#  dense_8 (Dense)             (None, 10)                1010
#
# ...
# Total params: 133,860
# Trainable params: 133,860
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model8.fit(x=x_train, y=y_train, epochs=100)
plt.plot(history.history['loss'])
plt.show()
test_loss = model8.evaluate(x=x_test, y=y_test)
print("Training loss = {}".format(test_loss))
# Out:
# Epoch 1/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4425
# Epoch 2/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2138
# Epoch 3/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1569
# Epoch 4/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1212
# Epoch 5/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0968
# Epoch 6/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0795
# Epoch 7/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0663
# Epoch 8/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0548
# Epoch 9/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0466
# Epoch 10/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0383
# Epoch 11/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0325
# Epoch 12/100
# ...

# %%
model9 = tf.keras.Sequential([
    tf.keras.Input(shape=(28,28)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(150,activation="tanh"),
    tf.keras.layers.Dense(100,activation="tanh"),
    tf.keras.layers.Dense(10,activation="softmax")
])
model9.compile(optimizer="adam",loss="sparse_categorical_crossentropy")
model9.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten_3 (Flatten)         (None, 784)               0
#
#  dense_9 (Dense)             (None, 150)               117750
#
#  dense_10 (Dense)            (None, 100)               15100
#
#  dense_11 (Dense)            (None, 10)                1010
#
# ...
# Total params: 133,860
# Trainable params: 133,860
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model9.fit(x=x_train, y=y_train, epochs=100)
plt.plot(history.history['loss'])
plt.show()
test_loss = model9.evaluate(x=x_test, y=y_test)
print("Training loss = {}".format(test_loss))
# Out:
# Epoch 1/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4410
# Epoch 2/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2183
# Epoch 3/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1619
# Epoch 4/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1250
# Epoch 5/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0993
# Epoch 6/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0819
# Epoch 7/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0679
# Epoch 8/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0568
# Epoch 9/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0484
# Epoch 10/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0400
# Epoch 11/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0341
# Epoch 12/100
# ...

# %%
model10 = tf.keras.Sequential([
    tf.keras.Input(shape=(28,28)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(150,activation="relu"),
    tf.keras.layers.Dense(100,activation="sigmoid"),
    tf.keras.layers.Dense(10,activation="softmax")
])
model10.compile(optimizer="adam",loss="sparse_categorical_crossentropy")
model10.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten_4 (Flatten)         (None, 784)               0
#
#  dense_12 (Dense)            (None, 150)               117750
#
#  dense_13 (Dense)            (None, 100)               15100
#
#  dense_14 (Dense)            (None, 10)                1010
#
# ...
# Total params: 133,860
# Trainable params: 133,860
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model10.fit(x=x_train, y=y_train, epochs=100)
plt.plot(history.history['loss'])
plt.show()
test_loss = model10.evaluate(x=x_test, y=y_test)
print("Training loss = {}".format(test_loss))
# Out:
# Epoch 1/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4276
# Epoch 2/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2126
# Epoch 3/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1558
# Epoch 4/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1189
# Epoch 5/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0945
# Epoch 6/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0766
# Epoch 7/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0633
# Epoch 8/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0522
# Epoch 9/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0435
# Epoch 10/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0362
# Epoch 11/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0303
# Epoch 12/100
# ...

# %%
model11 = tf.keras.Sequential([
    tf.keras.Input(shape=(28,28)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(150,activation="relu"),
    tf.keras.layers.Dense(100,activation="relu"),
    tf.keras.layers.Dense(10,activation="softmax")
])
model11.compile(optimizer="adam",loss="sparse_categorical_crossentropy")
model11.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten_5 (Flatten)         (None, 784)               0
#
#  dense_15 (Dense)            (None, 150)               117750
#
#  dense_16 (Dense)            (None, 100)               15100
#
#  dense_17 (Dense)            (None, 10)                1010
#
# ...
# Total params: 133,860
# Trainable params: 133,860
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model11.fit(x=x_train, y=y_train, epochs=100)
plt.plot(history.history['loss'])
plt.show()
test_loss = model11.evaluate(x=x_test, y=y_test)
print("Training loss = {}".format(test_loss))
# Out:
# Epoch 1/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4364
# Epoch 2/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2130
# Epoch 3/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1566
# Epoch 4/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1214
# Epoch 5/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0958
# Epoch 6/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0784
# Epoch 7/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0656
# Epoch 8/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0548
# Epoch 9/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0459
# Epoch 10/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0378
# Epoch 11/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0318
# Epoch 12/100
# ...

# %%
model12 = tf.keras.Sequential([
    tf.keras.Input(shape=(28,28)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(150,activation="relu"),
    tf.keras.layers.Dense(100,activation="tanh"),
    tf.keras.layers.Dense(10,activation="softmax")
])
model12.compile(optimizer="adam",loss="sparse_categorical_crossentropy")
model12.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten_6 (Flatten)         (None, 784)               0
#
#  dense_18 (Dense)            (None, 150)               117750
#
#  dense_19 (Dense)            (None, 100)               15100
#
#  dense_20 (Dense)            (None, 10)                1010
#
# ...
# Total params: 133,860
# Trainable params: 133,860
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model12.fit(x=x_train, y=y_train, epochs=100)
plt.plot(history.history['loss'])
plt.show()
test_loss = model12.evaluate(x=x_test, y=y_test)
print("Training loss = {}".format(test_loss))
# Out:
# Epoch 1/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4334
# Epoch 2/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2135
# Epoch 3/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1575
# Epoch 4/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1212
# Epoch 5/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0954
# Epoch 6/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0781
# Epoch 7/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0634
# Epoch 8/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0525
# Epoch 9/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0429
# Epoch 10/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0356
# Epoch 11/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0298
# Epoch 12/100
# ...

# %%
model13 = tf.keras.Sequential([
    tf.keras.Input(shape=(28,28)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(100,activation="sigmoid"),
    tf.keras.layers.Dense(10,activation="softmax")
])
model13.compile(optimizer="adam",loss="sparse_categorical_crossentropy")
model13.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 100)               78500
#
#  dense_1 (Dense)             (None, 10)                1010
#
# ...
# Total params: 79,510
# Trainable params: 79,510
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model13.fit(x=x_train, y=y_train, epochs=100)
plt.plot(history.history['loss'])
plt.show()
test_loss = model13.evaluate(x=x_test, y=y_test)
print("Training loss = {}".format(test_loss))
# Out:
# Epoch 1/100
# 1875/1875 [==============================] - 10s 2ms/step - loss: 0.5268
# Epoch 2/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2553
# Epoch 3/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1996
# Epoch 4/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1646
# Epoch 5/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1385
# Epoch 6/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1186
# Epoch 7/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1031
# Epoch 8/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0905
# Epoch 9/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0800
# Epoch 10/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0711
# Epoch 11/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0635
# Epoch 12/100
# ...

# %%
model14 = tf.keras.Sequential([
    tf.keras.Input(shape=(28,28)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(100,activation="tanh"),
    tf.keras.layers.Dense(10,activation="softmax")
])
model14.compile(optimizer="adam",loss="sparse_categorical_crossentropy")
model14.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten_1 (Flatten)         (None, 784)               0
#
#  dense_2 (Dense)             (None, 100)               78500
#
#  dense_3 (Dense)             (None, 10)                1010
#
# ...
# Total params: 79,510
# Trainable params: 79,510
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model14.fit(x=x_train, y=y_train, epochs=100)
plt.plot(history.history['loss'])
plt.show()
test_loss = model14.evaluate(x=x_test, y=y_test)
print("Training loss = {}".format(test_loss))
# Out:
# Epoch 1/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3565
# Epoch 2/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2000
# Epoch 3/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1427
# Epoch 4/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1089
# Epoch 5/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0862
# Epoch 6/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0700
# Epoch 7/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0572
# Epoch 8/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0472
# Epoch 9/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0393
# Epoch 10/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0331
# Epoch 11/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0265
# Epoch 12/100
# ...

# %%
model15 = tf.keras.Sequential([
    tf.keras.Input(shape=(28,28)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(100,activation="relu"),
    tf.keras.layers.Dense(10,activation="softmax")
])
model15.compile(optimizer="adam",loss="sparse_categorical_crossentropy")
model15.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten_2 (Flatten)         (None, 784)               0
#
#  dense_4 (Dense)             (None, 100)               78500
#
#  dense_5 (Dense)             (None, 10)                1010
#
# ...
# Total params: 79,510
# Trainable params: 79,510
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model15.fit(x=x_train, y=y_train, epochs=100)
plt.plot(history.history['loss'])
plt.show()
test_loss = model15.evaluate(x=x_test, y=y_test)
print("Training loss = {}".format(test_loss))
# Out:
# Epoch 1/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3341
# Epoch 2/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1565
# Epoch 3/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1107
# Epoch 4/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0843
# Epoch 5/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0673
# Epoch 6/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0541
# Epoch 7/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0446
# Epoch 8/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0363
# Epoch 9/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0298
# Epoch 10/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0246
# Epoch 11/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0204
# Epoch 12/100
# ...
